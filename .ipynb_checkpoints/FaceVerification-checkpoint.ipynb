# %% [markdown]
# # Face Recognition
#
# ---
#
# Ever wonder how hard it is to tell who someone is?
#
# I have always wanted to try and build a security app that only allows in people that it recognizes. I decided that I wanted to attempt to create a few machine learning models to tackle face recognition. Face recognition can simply be seen as a classification problem, but that requires retraining whenever you want to add someone new into the database. Instead, I am focusing on checking whether or not two pictures are of the same person.
#
# ## Table of Contents
# * [Getting the Data](#getting_data)
# * [Building a Basic Model](#basic_model)
# * [Basic Model Results](#basic_model_results)
# * [What's The Issue?](#issue)
# * [Getting More Data](#more_data)
# * [Results with More Data](#more_data_results)
# * [Conclusion](#conclusion)

# %% [markdown]
# <a id='getting_data'></a>
# ## Getting the Data
#
# To start building this model, some form of data is needed to train on. I didn't want to manually collect a ton of images of my friends. Instead, I downloaded the [Labeled Faces in the Wild(LFW) Dataset](http://vis-www.cs.umass.edu/lfw/index.html). This dataset is commonly used in order to test the quality of facial recognition algorithms. Because the model is going to learn whether or not two pictures are of the same person, it should be able to not only recognize these faces, but the face of anyone given a single image of them.
#
# Luckily for me, the dataset is part of the sklearn library. The dataset is quite large and may not run on a lot of hardware. In order to make it work happily on my computer with the model, I saved it to disk as a numpy array. I kept them in color because I believe that skin color can be a important way to tell people apart.

# %%
from sklearn.datasets import fetch_lfw_pairs
import numpy as np
from os.path import isfile


if not isfile('lfw_train_pairs.npy') or not isfile('lfw_train_target.npy'): 
    lfw_train = fetch_lfw_pairs(resize=0.8, color=True)
    np.save('lfw_train_pairs', lfw_train.pairs)
    np.save('lfw_train_target', lfw_train.target)
    lfw_train = None
if not isfile('lfw_test_pairs.npy') or not isfile('lfw_test_target.npy'): 
    lfw_test = fetch_lfw_pairs(resize=0.8, color=True, subset='test')
    np.save('lfw_test_pairs', lfw_test.pairs)
    np.save('lfw_test_target', lfw_test.target)
    lfw_test = None

trainX = np.load('lfw_train_pairs.npy', mmap_mode='r')
trainY = np.load('lfw_train_target.npy', mmap_mode='r')
testX = np.load('lfw_test_pairs.npy', mmap_mode='r')
testY = np.load('lfw_test_target.npy', mmap_mode='r')
print(trainX.shape)
print(testX.shape)
# Out:
# (2200, 2, 100, 75, 3)
# (1000, 2, 100, 75, 3)

# %% [markdown]
# In order to check that the data downloaded well and to get a better idea of what the images look like, I am displaying 5 images from the dataset.

# %%
import matplotlib.pyplot as plt
from keras.preprocessing.image import array_to_img
from random import randint

for i in range(5):
    plt.subplot(2, 5, i+1)
    plt.axis('off')
    r = randint(0, trainX.shape[0]-1)
    plt.imshow(array_to_img(trainX[r,0]))
    plt.subplot(2, 5, i+6)
    plt.axis('off')
    plt.imshow(array_to_img(trainX[r,1]))

plt.show()

# %% [markdown]
# <a id='basic_model'></a>
# ## Building a Basic Model
#
# To start off, I am going to use a rather easy to implement model. I am going to run both images through a convolutional neural network and then compare the results with a fully connected layer. I will be using a pretrained InceptionV3 as the core for image processing. In Keras, InceptionV3 will take as input images larger than 139 by 139 and smaller than 300 by 300 and output a vector of numbers related to the image.
#
# Here is how the basic processing will look:
#     1. 2 Images as input
#     2. Images processed separately through InceptionV3
#     3. Output tensors for both images are then concatenated together
#     4. Data is run through fully connected layer
#     5. Output of whether the images are of the same face(1) or not(0)
#  It is important to note that InceptionV3 is already trained and its weights should not be modified.

# %%
from keras.layers import Input, concatenate, GlobalAveragePooling2D, Dense, Dropout, Lambda
from keras.models import Model
from keras.optimizers import Adam
from keras.applications import Xception
from keras.applications.xception import preprocess_input

def compile_model():

    input1 = Input(shape=trainX.shape[2:])
    input2 = Input(shape=trainX.shape[2:])
    
    preprocess1 = Lambda(lambda x: preprocess_input(x))(input1)
    preprocess2 = Lambda(lambda x: preprocess_input(x))(input2)
    #Load two Inception nets
    cnn1 = Xception(include_top=False, pooling='avg', input_tensor=preprocess1)
    cnn2 = Xception(include_top=False, pooling='avg', input_tensor=preprocess2)

    #Stop training exept for the last few layers
    #:-27
    for layer in cnn1.layers:
        layer.trainable = False
    for layer in cnn2.layers:
        layer.trainable = False
        
    #Rename layers to stop conflicts
    for layer in cnn2.layers:
        layer.name = layer.name + '-1'

    #add fully conneced layers
    x = concatenate([cnn1.output, cnn2.output], axis=1)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.5)(x)
    out = Dense(1, activation='sigmoid')(x)

    #compile model
    model = Model([input1, input2], out)
    optimizer = Adam()
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
    return model
base_model = compile_model()
print(base_model.summary())
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_3 (InputLayer)             (None, 100, 75, 3)    0
# ____________________________________________________________________________________________________
# input_4-1 (InputLayer)           (None, 100, 75, 3)    0
# ____________________________________________________________________________________________________
# lambda_3 (Lambda)                (None, 100, 75, 3)    0           input_3[0][0]
# ____________________________________________________________________________________________________
# lambda_4-1 (Lambda)              (None, 100, 75, 3)    0           input_4-1[0][0]
# ____________________________________________________________________________________________________
# block1_conv1 (Conv2D)            (None, 49, 37, 32)    864         lambda_3[0][0]
# ____________________________________________________________________________________________________
# block1_conv1-1 (Conv2D)          (None, 49, 37, 32)    864         lambda_4-1[0][0]
# ____________________________________________________________________________________________________
# block1_conv1_bn (BatchNormalizat (None, 49, 37, 32)    128         block1_conv1[0][0]
# ____________________________________________________________________________________________________
# block1_conv1_bn-1 (BatchNormaliz (None, 49, 37, 32)    128         block1_conv1-1[0][0]
# ____________________________________________________________________________________________________
# block1_conv1_act (Activation)    (None, 49, 37, 32)    0           block1_conv1_bn[0][0]
# ____________________________________________________________________________________________________
# block1_conv1_act-1 (Activation)  (None, 49, 37, 32)    0           block1_conv1_bn-1[0][0]
# ____________________________________________________________________________________________________
# block1_conv2 (Conv2D)            (None, 47, 35, 64)    18432       block1_conv1_act[0][0]
# ____________________________________________________________________________________________________
# block1_conv2-1 (Conv2D)          (None, 47, 35, 64)    18432       block1_conv1_act-1[0][0]
# ____________________________________________________________________________________________________
# block1_conv2_bn (BatchNormalizat (None, 47, 35, 64)    256         block1_conv2[0][0]
# ____________________________________________________________________________________________________
# block1_conv2_bn-1 (BatchNormaliz (None, 47, 35, 64)    256         block1_conv2-1[0][0]
# ____________________________________________________________________________________________________
# block1_conv2_act (Activation)    (None, 47, 35, 64)    0           block1_conv2_bn[0][0]
# ____________________________________________________________________________________________________
# block1_conv2_act-1 (Activation)  (None, 47, 35, 64)    0           block1_conv2_bn-1[0][0]
# ____________________________________________________________________________________________________
# block2_sepconv1 (SeparableConv2D (None, 47, 35, 128)   8768        block1_conv2_act[0][0]
# ____________________________________________________________________________________________________
# block2_sepconv1-1 (SeparableConv (None, 47, 35, 128)   8768        block1_conv2_act-1[0][0]
# ____________________________________________________________________________________________________
# block2_sepconv1_bn (BatchNormali (None, 47, 35, 128)   512         block2_sepconv1[0][0]
# ____________________________________________________________________________________________________
# block2_sepconv1_bn-1 (BatchNorma (None, 47, 35, 128)   512         block2_sepconv1-1[0][0]
# ____________________________________________________________________________________________________
# block2_sepconv2_act (Activation) (None, 47, 35, 128)   0           block2_sepconv1_bn[0][0]
# ____________________________________________________________________________________________________
# block2_sepconv2_act-1 (Activatio (None, 47, 35, 128)   0           block2_sepconv1_bn-1[0][0]
# ____________________________________________________________________________________________________
# block2_sepconv2 (SeparableConv2D (None, 47, 35, 128)   17536       block2_sepconv2_act[0][0]
# ____________________________________________________________________________________________________
# block2_sepconv2-1 (SeparableConv (None, 47, 35, 128)   17536       block2_sepconv2_act-1[0][0]
# ____________________________________________________________________________________________________
# block2_sepconv2_bn (BatchNormali (None, 47, 35, 128)   512         block2_sepconv2[0][0]
# ____________________________________________________________________________________________________
# conv2d_9 (Conv2D)                (None, 24, 18, 128)   8192        block1_conv2_act[0][0]
# ____________________________________________________________________________________________________
# block2_sepconv2_bn-1 (BatchNorma (None, 47, 35, 128)   512         block2_sepconv2-1[0][0]
# ____________________________________________________________________________________________________
# conv2d_13-1 (Conv2D)             (None, 24, 18, 128)   8192        block1_conv2_act-1[0][0]
# ____________________________________________________________________________________________________
# block2_pool (MaxPooling2D)       (None, 24, 18, 128)   0           block2_sepconv2_bn[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_9 (BatchNorm (None, 24, 18, 128)   512         conv2d_9[0][0]
# ____________________________________________________________________________________________________
# block2_pool-1 (MaxPooling2D)     (None, 24, 18, 128)   0           block2_sepconv2_bn-1[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_13-1 (BatchN (None, 24, 18, 128)   512         conv2d_13-1[0][0]
# ____________________________________________________________________________________________________
# add_25 (Add)                     (None, 24, 18, 128)   0           block2_pool[0][0]
#                                                                    batch_normalization_9[0][0]
# ____________________________________________________________________________________________________
# add_37-1 (Add)                   (None, 24, 18, 128)   0           block2_pool-1[0][0]
#                                                                    batch_normalization_13-1[0][0]
# ____________________________________________________________________________________________________
# block3_sepconv1_act (Activation) (None, 24, 18, 128)   0           add_25[0][0]
# ____________________________________________________________________________________________________
# block3_sepconv1_act-1 (Activatio (None, 24, 18, 128)   0           add_37-1[0][0]
# ____________________________________________________________________________________________________
# block3_sepconv1 (SeparableConv2D (None, 24, 18, 256)   33920       block3_sepconv1_act[0][0]
# ____________________________________________________________________________________________________
# block3_sepconv1-1 (SeparableConv (None, 24, 18, 256)   33920       block3_sepconv1_act-1[0][0]
# ____________________________________________________________________________________________________
# block3_sepconv1_bn (BatchNormali (None, 24, 18, 256)   1024        block3_sepconv1[0][0]
# ____________________________________________________________________________________________________
# block3_sepconv1_bn-1 (BatchNorma (None, 24, 18, 256)   1024        block3_sepconv1-1[0][0]
# ____________________________________________________________________________________________________
# block3_sepconv2_act (Activation) (None, 24, 18, 256)   0           block3_sepconv1_bn[0][0]
# ____________________________________________________________________________________________________
# block3_sepconv2_act-1 (Activatio (None, 24, 18, 256)   0           block3_sepconv1_bn-1[0][0]
# ____________________________________________________________________________________________________
# block3_sepconv2 (SeparableConv2D (None, 24, 18, 256)   67840       block3_sepconv2_act[0][0]
# ____________________________________________________________________________________________________
# block3_sepconv2-1 (SeparableConv (None, 24, 18, 256)   67840       block3_sepconv2_act-1[0][0]
# ____________________________________________________________________________________________________
# block3_sepconv2_bn (BatchNormali (None, 24, 18, 256)   1024        block3_sepconv2[0][0]
# ____________________________________________________________________________________________________
# conv2d_10 (Conv2D)               (None, 12, 9, 256)    32768       add_25[0][0]
# ____________________________________________________________________________________________________
# block3_sepconv2_bn-1 (BatchNorma (None, 24, 18, 256)   1024        block3_sepconv2-1[0][0]
# ____________________________________________________________________________________________________
# conv2d_14-1 (Conv2D)             (None, 12, 9, 256)    32768       add_37-1[0][0]
# ____________________________________________________________________________________________________
# block3_pool (MaxPooling2D)       (None, 12, 9, 256)    0           block3_sepconv2_bn[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_10 (BatchNor (None, 12, 9, 256)    1024        conv2d_10[0][0]
# ____________________________________________________________________________________________________
# block3_pool-1 (MaxPooling2D)     (None, 12, 9, 256)    0           block3_sepconv2_bn-1[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_14-1 (BatchN (None, 12, 9, 256)    1024        conv2d_14-1[0][0]
# ____________________________________________________________________________________________________
# add_26 (Add)                     (None, 12, 9, 256)    0           block3_pool[0][0]
#                                                                    batch_normalization_10[0][0]
# ____________________________________________________________________________________________________
# add_38-1 (Add)                   (None, 12, 9, 256)    0           block3_pool-1[0][0]
#                                                                    batch_normalization_14-1[0][0]
# ____________________________________________________________________________________________________
# block4_sepconv1_act (Activation) (None, 12, 9, 256)    0           add_26[0][0]
# ____________________________________________________________________________________________________
# block4_sepconv1_act-1 (Activatio (None, 12, 9, 256)    0           add_38-1[0][0]
# ____________________________________________________________________________________________________
# block4_sepconv1 (SeparableConv2D (None, 12, 9, 728)    188672      block4_sepconv1_act[0][0]
# ____________________________________________________________________________________________________
# block4_sepconv1-1 (SeparableConv (None, 12, 9, 728)    188672      block4_sepconv1_act-1[0][0]
# ____________________________________________________________________________________________________
# block4_sepconv1_bn (BatchNormali (None, 12, 9, 728)    2912        block4_sepconv1[0][0]
# ____________________________________________________________________________________________________
# block4_sepconv1_bn-1 (BatchNorma (None, 12, 9, 728)    2912        block4_sepconv1-1[0][0]
# ____________________________________________________________________________________________________
# block4_sepconv2_act (Activation) (None, 12, 9, 728)    0           block4_sepconv1_bn[0][0]
# ____________________________________________________________________________________________________
# block4_sepconv2_act-1 (Activatio (None, 12, 9, 728)    0           block4_sepconv1_bn-1[0][0]
# ____________________________________________________________________________________________________
# block4_sepconv2 (SeparableConv2D (None, 12, 9, 728)    536536      block4_sepconv2_act[0][0]
# ____________________________________________________________________________________________________
# block4_sepconv2-1 (SeparableConv (None, 12, 9, 728)    536536      block4_sepconv2_act-1[0][0]
# ____________________________________________________________________________________________________
# block4_sepconv2_bn (BatchNormali (None, 12, 9, 728)    2912        block4_sepconv2[0][0]
# ____________________________________________________________________________________________________
# conv2d_11 (Conv2D)               (None, 6, 5, 728)     186368      add_26[0][0]
# ____________________________________________________________________________________________________
# block4_sepconv2_bn-1 (BatchNorma (None, 12, 9, 728)    2912        block4_sepconv2-1[0][0]
# ____________________________________________________________________________________________________
# conv2d_15-1 (Conv2D)             (None, 6, 5, 728)     186368      add_38-1[0][0]
# ____________________________________________________________________________________________________
# block4_pool (MaxPooling2D)       (None, 6, 5, 728)     0           block4_sepconv2_bn[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_11 (BatchNor (None, 6, 5, 728)     2912        conv2d_11[0][0]
# ____________________________________________________________________________________________________
# block4_pool-1 (MaxPooling2D)     (None, 6, 5, 728)     0           block4_sepconv2_bn-1[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_15-1 (BatchN (None, 6, 5, 728)     2912        conv2d_15-1[0][0]
# ____________________________________________________________________________________________________
# add_27 (Add)                     (None, 6, 5, 728)     0           block4_pool[0][0]
#                                                                    batch_normalization_11[0][0]
# ____________________________________________________________________________________________________
# add_39-1 (Add)                   (None, 6, 5, 728)     0           block4_pool-1[0][0]
#                                                                    batch_normalization_15-1[0][0]
# ____________________________________________________________________________________________________
# block5_sepconv1_act (Activation) (None, 6, 5, 728)     0           add_27[0][0]
# ____________________________________________________________________________________________________
# block5_sepconv1_act-1 (Activatio (None, 6, 5, 728)     0           add_39-1[0][0]
# ____________________________________________________________________________________________________
# block5_sepconv1 (SeparableConv2D (None, 6, 5, 728)     536536      block5_sepconv1_act[0][0]
# ____________________________________________________________________________________________________
# block5_sepconv1-1 (SeparableConv (None, 6, 5, 728)     536536      block5_sepconv1_act-1[0][0]
# ____________________________________________________________________________________________________
# block5_sepconv1_bn (BatchNormali (None, 6, 5, 728)     2912        block5_sepconv1[0][0]
# ____________________________________________________________________________________________________
# block5_sepconv1_bn-1 (BatchNorma (None, 6, 5, 728)     2912        block5_sepconv1-1[0][0]
# ____________________________________________________________________________________________________
# block5_sepconv2_act (Activation) (None, 6, 5, 728)     0           block5_sepconv1_bn[0][0]
# ____________________________________________________________________________________________________
# block5_sepconv2_act-1 (Activatio (None, 6, 5, 728)     0           block5_sepconv1_bn-1[0][0]
# ____________________________________________________________________________________________________
# block5_sepconv2 (SeparableConv2D (None, 6, 5, 728)     536536      block5_sepconv2_act[0][0]
# ____________________________________________________________________________________________________
# block5_sepconv2-1 (SeparableConv (None, 6, 5, 728)     536536      block5_sepconv2_act-1[0][0]
# ____________________________________________________________________________________________________
# block5_sepconv2_bn (BatchNormali (None, 6, 5, 728)     2912        block5_sepconv2[0][0]
# ____________________________________________________________________________________________________
# block5_sepconv2_bn-1 (BatchNorma (None, 6, 5, 728)     2912        block5_sepconv2-1[0][0]
# ____________________________________________________________________________________________________
# block5_sepconv3_act (Activation) (None, 6, 5, 728)     0           block5_sepconv2_bn[0][0]
# ____________________________________________________________________________________________________
# block5_sepconv3_act-1 (Activatio (None, 6, 5, 728)     0           block5_sepconv2_bn-1[0][0]
# ____________________________________________________________________________________________________
# block5_sepconv3 (SeparableConv2D (None, 6, 5, 728)     536536      block5_sepconv3_act[0][0]
# ____________________________________________________________________________________________________
# block5_sepconv3-1 (SeparableConv (None, 6, 5, 728)     536536      block5_sepconv3_act-1[0][0]
# ____________________________________________________________________________________________________
# block5_sepconv3_bn (BatchNormali (None, 6, 5, 728)     2912        block5_sepconv3[0][0]
# ____________________________________________________________________________________________________
# block5_sepconv3_bn-1 (BatchNorma (None, 6, 5, 728)     2912        block5_sepconv3-1[0][0]
# ____________________________________________________________________________________________________
# add_28 (Add)                     (None, 6, 5, 728)     0           block5_sepconv3_bn[0][0]
#                                                                    add_27[0][0]
# ____________________________________________________________________________________________________
# add_40-1 (Add)                   (None, 6, 5, 728)     0           block5_sepconv3_bn-1[0][0]
#                                                                    add_39-1[0][0]
# ____________________________________________________________________________________________________
# block6_sepconv1_act (Activation) (None, 6, 5, 728)     0           add_28[0][0]
# ____________________________________________________________________________________________________
# block6_sepconv1_act-1 (Activatio (None, 6, 5, 728)     0           add_40-1[0][0]
# ____________________________________________________________________________________________________
# block6_sepconv1 (SeparableConv2D (None, 6, 5, 728)     536536      block6_sepconv1_act[0][0]
# ____________________________________________________________________________________________________
# block6_sepconv1-1 (SeparableConv (None, 6, 5, 728)     536536      block6_sepconv1_act-1[0][0]
# ____________________________________________________________________________________________________
# block6_sepconv1_bn (BatchNormali (None, 6, 5, 728)     2912        block6_sepconv1[0][0]
# ____________________________________________________________________________________________________
# block6_sepconv1_bn-1 (BatchNorma (None, 6, 5, 728)     2912        block6_sepconv1-1[0][0]
# ____________________________________________________________________________________________________
# block6_sepconv2_act (Activation) (None, 6, 5, 728)     0           block6_sepconv1_bn[0][0]
# ____________________________________________________________________________________________________
# block6_sepconv2_act-1 (Activatio (None, 6, 5, 728)     0           block6_sepconv1_bn-1[0][0]
# ____________________________________________________________________________________________________
# block6_sepconv2 (SeparableConv2D (None, 6, 5, 728)     536536      block6_sepconv2_act[0][0]
# ____________________________________________________________________________________________________
# block6_sepconv2-1 (SeparableConv (None, 6, 5, 728)     536536      block6_sepconv2_act-1[0][0]
# ____________________________________________________________________________________________________
# block6_sepconv2_bn (BatchNormali (None, 6, 5, 728)     2912        block6_sepconv2[0][0]
# ____________________________________________________________________________________________________
# block6_sepconv2_bn-1 (BatchNorma (None, 6, 5, 728)     2912        block6_sepconv2-1[0][0]
# ____________________________________________________________________________________________________
# block6_sepconv3_act (Activation) (None, 6, 5, 728)     0           block6_sepconv2_bn[0][0]
# ____________________________________________________________________________________________________
# block6_sepconv3_act-1 (Activatio (None, 6, 5, 728)     0           block6_sepconv2_bn-1[0][0]
# ____________________________________________________________________________________________________
# block6_sepconv3 (SeparableConv2D (None, 6, 5, 728)     536536      block6_sepconv3_act[0][0]
# ____________________________________________________________________________________________________
# block6_sepconv3-1 (SeparableConv (None, 6, 5, 728)     536536      block6_sepconv3_act-1[0][0]
# ____________________________________________________________________________________________________
# block6_sepconv3_bn (BatchNormali (None, 6, 5, 728)     2912        block6_sepconv3[0][0]
# ____________________________________________________________________________________________________
# block6_sepconv3_bn-1 (BatchNorma (None, 6, 5, 728)     2912        block6_sepconv3-1[0][0]
# ____________________________________________________________________________________________________
# add_29 (Add)                     (None, 6, 5, 728)     0           block6_sepconv3_bn[0][0]
#                                                                    add_28[0][0]
# ____________________________________________________________________________________________________
# add_41-1 (Add)                   (None, 6, 5, 728)     0           block6_sepconv3_bn-1[0][0]
#                                                                    add_40-1[0][0]
# ____________________________________________________________________________________________________
# block7_sepconv1_act (Activation) (None, 6, 5, 728)     0           add_29[0][0]
# ____________________________________________________________________________________________________
# block7_sepconv1_act-1 (Activatio (None, 6, 5, 728)     0           add_41-1[0][0]
# ____________________________________________________________________________________________________
# block7_sepconv1 (SeparableConv2D (None, 6, 5, 728)     536536      block7_sepconv1_act[0][0]
# ____________________________________________________________________________________________________
# block7_sepconv1-1 (SeparableConv (None, 6, 5, 728)     536536      block7_sepconv1_act-1[0][0]
# ____________________________________________________________________________________________________
# block7_sepconv1_bn (BatchNormali (None, 6, 5, 728)     2912        block7_sepconv1[0][0]
# ____________________________________________________________________________________________________
# block7_sepconv1_bn-1 (BatchNorma (None, 6, 5, 728)     2912        block7_sepconv1-1[0][0]
# ____________________________________________________________________________________________________
# block7_sepconv2_act (Activation) (None, 6, 5, 728)     0           block7_sepconv1_bn[0][0]
# ____________________________________________________________________________________________________
# block7_sepconv2_act-1 (Activatio (None, 6, 5, 728)     0           block7_sepconv1_bn-1[0][0]
# ____________________________________________________________________________________________________
# block7_sepconv2 (SeparableConv2D (None, 6, 5, 728)     536536      block7_sepconv2_act[0][0]
# ____________________________________________________________________________________________________
# block7_sepconv2-1 (SeparableConv (None, 6, 5, 728)     536536      block7_sepconv2_act-1[0][0]
# ____________________________________________________________________________________________________
# block7_sepconv2_bn (BatchNormali (None, 6, 5, 728)     2912        block7_sepconv2[0][0]
# ____________________________________________________________________________________________________
# block7_sepconv2_bn-1 (BatchNorma (None, 6, 5, 728)     2912        block7_sepconv2-1[0][0]
# ____________________________________________________________________________________________________
# block7_sepconv3_act (Activation) (None, 6, 5, 728)     0           block7_sepconv2_bn[0][0]
# ____________________________________________________________________________________________________
# block7_sepconv3_act-1 (Activatio (None, 6, 5, 728)     0           block7_sepconv2_bn-1[0][0]
# ____________________________________________________________________________________________________
# block7_sepconv3 (SeparableConv2D (None, 6, 5, 728)     536536      block7_sepconv3_act[0][0]
# ____________________________________________________________________________________________________
# block7_sepconv3-1 (SeparableConv (None, 6, 5, 728)     536536      block7_sepconv3_act-1[0][0]
# ____________________________________________________________________________________________________
# block7_sepconv3_bn (BatchNormali (None, 6, 5, 728)     2912        block7_sepconv3[0][0]
# ____________________________________________________________________________________________________
# block7_sepconv3_bn-1 (BatchNorma (None, 6, 5, 728)     2912        block7_sepconv3-1[0][0]
# ____________________________________________________________________________________________________
# add_30 (Add)                     (None, 6, 5, 728)     0           block7_sepconv3_bn[0][0]
#                                                                    add_29[0][0]
# ____________________________________________________________________________________________________
# add_42-1 (Add)                   (None, 6, 5, 728)     0           block7_sepconv3_bn-1[0][0]
#                                                                    add_41-1[0][0]
# ____________________________________________________________________________________________________
# block8_sepconv1_act (Activation) (None, 6, 5, 728)     0           add_30[0][0]
# ____________________________________________________________________________________________________
# block8_sepconv1_act-1 (Activatio (None, 6, 5, 728)     0           add_42-1[0][0]
# ____________________________________________________________________________________________________
# block8_sepconv1 (SeparableConv2D (None, 6, 5, 728)     536536      block8_sepconv1_act[0][0]
# ____________________________________________________________________________________________________
# block8_sepconv1-1 (SeparableConv (None, 6, 5, 728)     536536      block8_sepconv1_act-1[0][0]
# ____________________________________________________________________________________________________
# block8_sepconv1_bn (BatchNormali (None, 6, 5, 728)     2912        block8_sepconv1[0][0]
# ____________________________________________________________________________________________________
# block8_sepconv1_bn-1 (BatchNorma (None, 6, 5, 728)     2912        block8_sepconv1-1[0][0]
# ____________________________________________________________________________________________________
# block8_sepconv2_act (Activation) (None, 6, 5, 728)     0           block8_sepconv1_bn[0][0]
# ____________________________________________________________________________________________________
# block8_sepconv2_act-1 (Activatio (None, 6, 5, 728)     0           block8_sepconv1_bn-1[0][0]
# ____________________________________________________________________________________________________
# block8_sepconv2 (SeparableConv2D (None, 6, 5, 728)     536536      block8_sepconv2_act[0][0]
# ____________________________________________________________________________________________________
# block8_sepconv2-1 (SeparableConv (None, 6, 5, 728)     536536      block8_sepconv2_act-1[0][0]
# ____________________________________________________________________________________________________
# block8_sepconv2_bn (BatchNormali (None, 6, 5, 728)     2912        block8_sepconv2[0][0]
# ____________________________________________________________________________________________________
# block8_sepconv2_bn-1 (BatchNorma (None, 6, 5, 728)     2912        block8_sepconv2-1[0][0]
# ____________________________________________________________________________________________________
# block8_sepconv3_act (Activation) (None, 6, 5, 728)     0           block8_sepconv2_bn[0][0]
# ____________________________________________________________________________________________________
# block8_sepconv3_act-1 (Activatio (None, 6, 5, 728)     0           block8_sepconv2_bn-1[0][0]
# ____________________________________________________________________________________________________
# block8_sepconv3 (SeparableConv2D (None, 6, 5, 728)     536536      block8_sepconv3_act[0][0]
# ____________________________________________________________________________________________________
# block8_sepconv3-1 (SeparableConv (None, 6, 5, 728)     536536      block8_sepconv3_act-1[0][0]
# ____________________________________________________________________________________________________
# block8_sepconv3_bn (BatchNormali (None, 6, 5, 728)     2912        block8_sepconv3[0][0]
# ____________________________________________________________________________________________________
# block8_sepconv3_bn-1 (BatchNorma (None, 6, 5, 728)     2912        block8_sepconv3-1[0][0]
# ____________________________________________________________________________________________________
# add_31 (Add)                     (None, 6, 5, 728)     0           block8_sepconv3_bn[0][0]
#                                                                    add_30[0][0]
# ____________________________________________________________________________________________________
# add_43-1 (Add)                   (None, 6, 5, 728)     0           block8_sepconv3_bn-1[0][0]
#                                                                    add_42-1[0][0]
# ____________________________________________________________________________________________________
# block9_sepconv1_act (Activation) (None, 6, 5, 728)     0           add_31[0][0]
# ____________________________________________________________________________________________________
# block9_sepconv1_act-1 (Activatio (None, 6, 5, 728)     0           add_43-1[0][0]
# ____________________________________________________________________________________________________
# block9_sepconv1 (SeparableConv2D (None, 6, 5, 728)     536536      block9_sepconv1_act[0][0]
# ____________________________________________________________________________________________________
# block9_sepconv1-1 (SeparableConv (None, 6, 5, 728)     536536      block9_sepconv1_act-1[0][0]
# ____________________________________________________________________________________________________
# block9_sepconv1_bn (BatchNormali (None, 6, 5, 728)     2912        block9_sepconv1[0][0]
# ____________________________________________________________________________________________________
# block9_sepconv1_bn-1 (BatchNorma (None, 6, 5, 728)     2912        block9_sepconv1-1[0][0]
# ____________________________________________________________________________________________________
# block9_sepconv2_act (Activation) (None, 6, 5, 728)     0           block9_sepconv1_bn[0][0]
# ____________________________________________________________________________________________________
# block9_sepconv2_act-1 (Activatio (None, 6, 5, 728)     0           block9_sepconv1_bn-1[0][0]
# ____________________________________________________________________________________________________
# block9_sepconv2 (SeparableConv2D (None, 6, 5, 728)     536536      block9_sepconv2_act[0][0]
# ____________________________________________________________________________________________________
# block9_sepconv2-1 (SeparableConv (None, 6, 5, 728)     536536      block9_sepconv2_act-1[0][0]
# ____________________________________________________________________________________________________
# block9_sepconv2_bn (BatchNormali (None, 6, 5, 728)     2912        block9_sepconv2[0][0]
# ____________________________________________________________________________________________________
# block9_sepconv2_bn-1 (BatchNorma (None, 6, 5, 728)     2912        block9_sepconv2-1[0][0]
# ____________________________________________________________________________________________________
# block9_sepconv3_act (Activation) (None, 6, 5, 728)     0           block9_sepconv2_bn[0][0]
# ____________________________________________________________________________________________________
# block9_sepconv3_act-1 (Activatio (None, 6, 5, 728)     0           block9_sepconv2_bn-1[0][0]
# ____________________________________________________________________________________________________
# block9_sepconv3 (SeparableConv2D (None, 6, 5, 728)     536536      block9_sepconv3_act[0][0]
# ____________________________________________________________________________________________________
# block9_sepconv3-1 (SeparableConv (None, 6, 5, 728)     536536      block9_sepconv3_act-1[0][0]
# ____________________________________________________________________________________________________
# block9_sepconv3_bn (BatchNormali (None, 6, 5, 728)     2912        block9_sepconv3[0][0]
# ____________________________________________________________________________________________________
# block9_sepconv3_bn-1 (BatchNorma (None, 6, 5, 728)     2912        block9_sepconv3-1[0][0]
# ____________________________________________________________________________________________________
# add_32 (Add)                     (None, 6, 5, 728)     0           block9_sepconv3_bn[0][0]
#                                                                    add_31[0][0]
# ____________________________________________________________________________________________________
# add_44-1 (Add)                   (None, 6, 5, 728)     0           block9_sepconv3_bn-1[0][0]
#                                                                    add_43-1[0][0]
# ____________________________________________________________________________________________________
# block10_sepconv1_act (Activation (None, 6, 5, 728)     0           add_32[0][0]
# ____________________________________________________________________________________________________
# block10_sepconv1_act-1 (Activati (None, 6, 5, 728)     0           add_44-1[0][0]
# ____________________________________________________________________________________________________
# block10_sepconv1 (SeparableConv2 (None, 6, 5, 728)     536536      block10_sepconv1_act[0][0]
# ____________________________________________________________________________________________________
# block10_sepconv1-1 (SeparableCon (None, 6, 5, 728)     536536      block10_sepconv1_act-1[0][0]
# ____________________________________________________________________________________________________
# block10_sepconv1_bn (BatchNormal (None, 6, 5, 728)     2912        block10_sepconv1[0][0]
# ____________________________________________________________________________________________________
# block10_sepconv1_bn-1 (BatchNorm (None, 6, 5, 728)     2912        block10_sepconv1-1[0][0]
# ____________________________________________________________________________________________________
# block10_sepconv2_act (Activation (None, 6, 5, 728)     0           block10_sepconv1_bn[0][0]
# ____________________________________________________________________________________________________
# block10_sepconv2_act-1 (Activati (None, 6, 5, 728)     0           block10_sepconv1_bn-1[0][0]
# ____________________________________________________________________________________________________
# block10_sepconv2 (SeparableConv2 (None, 6, 5, 728)     536536      block10_sepconv2_act[0][0]
# ____________________________________________________________________________________________________
# block10_sepconv2-1 (SeparableCon (None, 6, 5, 728)     536536      block10_sepconv2_act-1[0][0]
# ____________________________________________________________________________________________________
# block10_sepconv2_bn (BatchNormal (None, 6, 5, 728)     2912        block10_sepconv2[0][0]
# ____________________________________________________________________________________________________
# block10_sepconv2_bn-1 (BatchNorm (None, 6, 5, 728)     2912        block10_sepconv2-1[0][0]
# ____________________________________________________________________________________________________
# block10_sepconv3_act (Activation (None, 6, 5, 728)     0           block10_sepconv2_bn[0][0]
# ____________________________________________________________________________________________________
# block10_sepconv3_act-1 (Activati (None, 6, 5, 728)     0           block10_sepconv2_bn-1[0][0]
# ____________________________________________________________________________________________________
# block10_sepconv3 (SeparableConv2 (None, 6, 5, 728)     536536      block10_sepconv3_act[0][0]
# ____________________________________________________________________________________________________
# block10_sepconv3-1 (SeparableCon (None, 6, 5, 728)     536536      block10_sepconv3_act-1[0][0]
# ____________________________________________________________________________________________________
# block10_sepconv3_bn (BatchNormal (None, 6, 5, 728)     2912        block10_sepconv3[0][0]
# ____________________________________________________________________________________________________
# block10_sepconv3_bn-1 (BatchNorm (None, 6, 5, 728)     2912        block10_sepconv3-1[0][0]
# ____________________________________________________________________________________________________
# add_33 (Add)                     (None, 6, 5, 728)     0           block10_sepconv3_bn[0][0]
#                                                                    add_32[0][0]
# ____________________________________________________________________________________________________
# add_45-1 (Add)                   (None, 6, 5, 728)     0           block10_sepconv3_bn-1[0][0]
#                                                                    add_44-1[0][0]
# ____________________________________________________________________________________________________
# block11_sepconv1_act (Activation (None, 6, 5, 728)     0           add_33[0][0]
# ____________________________________________________________________________________________________
# block11_sepconv1_act-1 (Activati (None, 6, 5, 728)     0           add_45-1[0][0]
# ____________________________________________________________________________________________________
# block11_sepconv1 (SeparableConv2 (None, 6, 5, 728)     536536      block11_sepconv1_act[0][0]
# ____________________________________________________________________________________________________
# block11_sepconv1-1 (SeparableCon (None, 6, 5, 728)     536536      block11_sepconv1_act-1[0][0]
# ____________________________________________________________________________________________________
# block11_sepconv1_bn (BatchNormal (None, 6, 5, 728)     2912        block11_sepconv1[0][0]
# ____________________________________________________________________________________________________
# block11_sepconv1_bn-1 (BatchNorm (None, 6, 5, 728)     2912        block11_sepconv1-1[0][0]
# ____________________________________________________________________________________________________
# block11_sepconv2_act (Activation (None, 6, 5, 728)     0           block11_sepconv1_bn[0][0]
# ____________________________________________________________________________________________________
# block11_sepconv2_act-1 (Activati (None, 6, 5, 728)     0           block11_sepconv1_bn-1[0][0]
# ____________________________________________________________________________________________________
# block11_sepconv2 (SeparableConv2 (None, 6, 5, 728)     536536      block11_sepconv2_act[0][0]
# ____________________________________________________________________________________________________
# block11_sepconv2-1 (SeparableCon (None, 6, 5, 728)     536536      block11_sepconv2_act-1[0][0]
# ____________________________________________________________________________________________________
# block11_sepconv2_bn (BatchNormal (None, 6, 5, 728)     2912        block11_sepconv2[0][0]
# ____________________________________________________________________________________________________
# block11_sepconv2_bn-1 (BatchNorm (None, 6, 5, 728)     2912        block11_sepconv2-1[0][0]
# ____________________________________________________________________________________________________
# block11_sepconv3_act (Activation (None, 6, 5, 728)     0           block11_sepconv2_bn[0][0]
# ____________________________________________________________________________________________________
# block11_sepconv3_act-1 (Activati (None, 6, 5, 728)     0           block11_sepconv2_bn-1[0][0]
# ____________________________________________________________________________________________________
# block11_sepconv3 (SeparableConv2 (None, 6, 5, 728)     536536      block11_sepconv3_act[0][0]
# ____________________________________________________________________________________________________
# block11_sepconv3-1 (SeparableCon (None, 6, 5, 728)     536536      block11_sepconv3_act-1[0][0]
# ____________________________________________________________________________________________________
# block11_sepconv3_bn (BatchNormal (None, 6, 5, 728)     2912        block11_sepconv3[0][0]
# ____________________________________________________________________________________________________
# block11_sepconv3_bn-1 (BatchNorm (None, 6, 5, 728)     2912        block11_sepconv3-1[0][0]
# ____________________________________________________________________________________________________
# add_34 (Add)                     (None, 6, 5, 728)     0           block11_sepconv3_bn[0][0]
#                                                                    add_33[0][0]
# ____________________________________________________________________________________________________
# add_46-1 (Add)                   (None, 6, 5, 728)     0           block11_sepconv3_bn-1[0][0]
#                                                                    add_45-1[0][0]
# ____________________________________________________________________________________________________
# block12_sepconv1_act (Activation (None, 6, 5, 728)     0           add_34[0][0]
# ____________________________________________________________________________________________________
# block12_sepconv1_act-1 (Activati (None, 6, 5, 728)     0           add_46-1[0][0]
# ____________________________________________________________________________________________________
# block12_sepconv1 (SeparableConv2 (None, 6, 5, 728)     536536      block12_sepconv1_act[0][0]
# ____________________________________________________________________________________________________
# block12_sepconv1-1 (SeparableCon (None, 6, 5, 728)     536536      block12_sepconv1_act-1[0][0]
# ____________________________________________________________________________________________________
# block12_sepconv1_bn (BatchNormal (None, 6, 5, 728)     2912        block12_sepconv1[0][0]
# ____________________________________________________________________________________________________
# block12_sepconv1_bn-1 (BatchNorm (None, 6, 5, 728)     2912        block12_sepconv1-1[0][0]
# ____________________________________________________________________________________________________
# block12_sepconv2_act (Activation (None, 6, 5, 728)     0           block12_sepconv1_bn[0][0]
# ____________________________________________________________________________________________________
# block12_sepconv2_act-1 (Activati (None, 6, 5, 728)     0           block12_sepconv1_bn-1[0][0]
# ____________________________________________________________________________________________________
# block12_sepconv2 (SeparableConv2 (None, 6, 5, 728)     536536      block12_sepconv2_act[0][0]
# ____________________________________________________________________________________________________
# block12_sepconv2-1 (SeparableCon (None, 6, 5, 728)     536536      block12_sepconv2_act-1[0][0]
# ____________________________________________________________________________________________________
# block12_sepconv2_bn (BatchNormal (None, 6, 5, 728)     2912        block12_sepconv2[0][0]
# ____________________________________________________________________________________________________
# block12_sepconv2_bn-1 (BatchNorm (None, 6, 5, 728)     2912        block12_sepconv2-1[0][0]
# ____________________________________________________________________________________________________
# block12_sepconv3_act (Activation (None, 6, 5, 728)     0           block12_sepconv2_bn[0][0]
# ____________________________________________________________________________________________________
# block12_sepconv3_act-1 (Activati (None, 6, 5, 728)     0           block12_sepconv2_bn-1[0][0]
# ____________________________________________________________________________________________________
# block12_sepconv3 (SeparableConv2 (None, 6, 5, 728)     536536      block12_sepconv3_act[0][0]
# ____________________________________________________________________________________________________
# block12_sepconv3-1 (SeparableCon (None, 6, 5, 728)     536536      block12_sepconv3_act-1[0][0]
# ____________________________________________________________________________________________________
# block12_sepconv3_bn (BatchNormal (None, 6, 5, 728)     2912        block12_sepconv3[0][0]
# ____________________________________________________________________________________________________
# block12_sepconv3_bn-1 (BatchNorm (None, 6, 5, 728)     2912        block12_sepconv3-1[0][0]
# ____________________________________________________________________________________________________
# add_35 (Add)                     (None, 6, 5, 728)     0           block12_sepconv3_bn[0][0]
#                                                                    add_34[0][0]
# ____________________________________________________________________________________________________
# add_47-1 (Add)                   (None, 6, 5, 728)     0           block12_sepconv3_bn-1[0][0]
#                                                                    add_46-1[0][0]
# ____________________________________________________________________________________________________
# block13_sepconv1_act (Activation (None, 6, 5, 728)     0           add_35[0][0]
# ____________________________________________________________________________________________________
# block13_sepconv1_act-1 (Activati (None, 6, 5, 728)     0           add_47-1[0][0]
# ____________________________________________________________________________________________________
# block13_sepconv1 (SeparableConv2 (None, 6, 5, 728)     536536      block13_sepconv1_act[0][0]
# ____________________________________________________________________________________________________
# block13_sepconv1-1 (SeparableCon (None, 6, 5, 728)     536536      block13_sepconv1_act-1[0][0]
# ____________________________________________________________________________________________________
# block13_sepconv1_bn (BatchNormal (None, 6, 5, 728)     2912        block13_sepconv1[0][0]
# ____________________________________________________________________________________________________
# block13_sepconv1_bn-1 (BatchNorm (None, 6, 5, 728)     2912        block13_sepconv1-1[0][0]
# ____________________________________________________________________________________________________
# block13_sepconv2_act (Activation (None, 6, 5, 728)     0           block13_sepconv1_bn[0][0]
# ____________________________________________________________________________________________________
# block13_sepconv2_act-1 (Activati (None, 6, 5, 728)     0           block13_sepconv1_bn-1[0][0]
# ____________________________________________________________________________________________________
# block13_sepconv2 (SeparableConv2 (None, 6, 5, 1024)    752024      block13_sepconv2_act[0][0]
# ____________________________________________________________________________________________________
# block13_sepconv2-1 (SeparableCon (None, 6, 5, 1024)    752024      block13_sepconv2_act-1[0][0]
# ____________________________________________________________________________________________________
# block13_sepconv2_bn (BatchNormal (None, 6, 5, 1024)    4096        block13_sepconv2[0][0]
# ____________________________________________________________________________________________________
# conv2d_12 (Conv2D)               (None, 3, 3, 1024)    745472      add_35[0][0]
# ____________________________________________________________________________________________________
# block13_sepconv2_bn-1 (BatchNorm (None, 6, 5, 1024)    4096        block13_sepconv2-1[0][0]
# ____________________________________________________________________________________________________
# conv2d_16-1 (Conv2D)             (None, 3, 3, 1024)    745472      add_47-1[0][0]
# ____________________________________________________________________________________________________
# block13_pool (MaxPooling2D)      (None, 3, 3, 1024)    0           block13_sepconv2_bn[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_12 (BatchNor (None, 3, 3, 1024)    4096        conv2d_12[0][0]
# ____________________________________________________________________________________________________
# block13_pool-1 (MaxPooling2D)    (None, 3, 3, 1024)    0           block13_sepconv2_bn-1[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_16-1 (BatchN (None, 3, 3, 1024)    4096        conv2d_16-1[0][0]
# ____________________________________________________________________________________________________
# add_36 (Add)                     (None, 3, 3, 1024)    0           block13_pool[0][0]
#                                                                    batch_normalization_12[0][0]
# ____________________________________________________________________________________________________
# add_48-1 (Add)                   (None, 3, 3, 1024)    0           block13_pool-1[0][0]
#                                                                    batch_normalization_16-1[0][0]
# ____________________________________________________________________________________________________
# block14_sepconv1 (SeparableConv2 (None, 3, 3, 1536)    1582080     add_36[0][0]
# ____________________________________________________________________________________________________
# block14_sepconv1-1 (SeparableCon (None, 3, 3, 1536)    1582080     add_48-1[0][0]
# ____________________________________________________________________________________________________
# block14_sepconv1_bn (BatchNormal (None, 3, 3, 1536)    6144        block14_sepconv1[0][0]
# ____________________________________________________________________________________________________
# block14_sepconv1_bn-1 (BatchNorm (None, 3, 3, 1536)    6144        block14_sepconv1-1[0][0]
# ____________________________________________________________________________________________________
# block14_sepconv1_act (Activation (None, 3, 3, 1536)    0           block14_sepconv1_bn[0][0]
# ____________________________________________________________________________________________________
# block14_sepconv1_act-1 (Activati (None, 3, 3, 1536)    0           block14_sepconv1_bn-1[0][0]
# ____________________________________________________________________________________________________
# block14_sepconv2 (SeparableConv2 (None, 3, 3, 2048)    3159552     block14_sepconv1_act[0][0]
# ____________________________________________________________________________________________________
# block14_sepconv2-1 (SeparableCon (None, 3, 3, 2048)    3159552     block14_sepconv1_act-1[0][0]
# ____________________________________________________________________________________________________
# block14_sepconv2_bn (BatchNormal (None, 3, 3, 2048)    8192        block14_sepconv2[0][0]
# ____________________________________________________________________________________________________
# block14_sepconv2_bn-1 (BatchNorm (None, 3, 3, 2048)    8192        block14_sepconv2-1[0][0]
# ____________________________________________________________________________________________________
# block14_sepconv2_act (Activation (None, 3, 3, 2048)    0           block14_sepconv2_bn[0][0]
# ____________________________________________________________________________________________________
# block14_sepconv2_act-1 (Activati (None, 3, 3, 2048)    0           block14_sepconv2_bn-1[0][0]
# ____________________________________________________________________________________________________
# global_average_pooling2d_3 (Glob (None, 2048)          0           block14_sepconv2_act[0][0]
# ____________________________________________________________________________________________________
# global_average_pooling2d_4-1 (Gl (None, 2048)          0           block14_sepconv2_act-1[0][0]
# ____________________________________________________________________________________________________
# concatenate_2 (Concatenate)      (None, 4096)          0           global_average_pooling2d_3[0][0]
#                                                                    global_average_pooling2d_4-1[0][0
# ____________________________________________________________________________________________________
# dense_4 (Dense)                  (None, 512)           2097664     concatenate_2[0][0]
# ____________________________________________________________________________________________________
# dropout_3 (Dropout)              (None, 512)           0           dense_4[0][0]
# ____________________________________________________________________________________________________
# dense_5 (Dense)                  (None, 128)           65664       dropout_3[0][0]
# ____________________________________________________________________________________________________
# dropout_4 (Dropout)              (None, 128)           0           dense_5[0][0]
# ____________________________________________________________________________________________________
# dense_6 (Dense)                  (None, 1)             129         dropout_4[0][0]
# ====================================================================================================
# Total params: 43,886,417
# Trainable params: 2,163,457
# Non-trainable params: 41,722,960
# ____________________________________________________________________________________________________
# None

# %% [markdown]
# Now that the model is compiled, it is time to fit the model to the data and see how it does against the validation set.

# %%
from keras.callbacks import ModelCheckpoint, TensorBoard
from os import listdir
from os.path import isfile, join
import pickle

files = [f for f in listdir('base_model') if isfile(join('base_model', f))]
if len(files) > 0:
    base_model.load_weights('base_model/'+sorted(files)[-1])
    base_history = pickle.load(open("base_model/history.p", "rb"))
else:
    filepath="base_model/weights-improvement-{epoch:02d}-{val_acc:.2f}.hdf5"
    checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=0, save_best_only=True, mode='max')
    tensorboard = TensorBoard(log_dir="logs/base_model")
    callbacks_list = [checkpoint, tensorboard]#, early_stopping]

    base_history = base_model.fit([trainX[:,0,:,:],trainX[:,1,:,:]],
              trainY, validation_data=([testX[:,0,:,:],testX[:,1,:,:]],testY),
              epochs=50, batch_size=64, callbacks=callbacks_list, verbose=0).history
    pickle.dump(base_history, open("base_model/history.p", "wb+"))

# %% [markdown]
# <a id='basic_model_results'></a>
# ## Basic Model Results
# The training is complete, but just looking at numbers is not the best way to tell how good a model is doing. In order to better understand the model, here are some graphs of the accuracy as it trained.

# %%
# summarize history for accuracy
plt.plot(base_history['acc'])
plt.plot(base_history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# This model learned the training data very well, but failed to really learn the testing data. The training accuracy manage to climb during all of training, but the validation barely managed to go above 50%. For further testing of the model, the best version of the model according to the validation set is used.

# %%
files = [f for f in listdir('base_model') if isfile(join('base_model', f))]
base_model.load_weights('base_model/'+sorted(files)[-1]) #Load best epoch model

# %% [markdown]
# Another important metric for binary classifiers is their ROC curve and the area under it. Here is the ROC and AUC.

# %%
from sklearn.metrics import auc, roc_curve

y_pred = base_model.predict([trainX[:,0,:,:],trainX[:,1,:,:]])

fpr, tpr, _ = roc_curve(trainY, y_pred)
roc_auc = auc(fpr, tpr)

plt.subplot(1, 2, 1)
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy',linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Train ROC')
plt.legend(loc="lower right")

y_pred = base_model.predict([testX[:,0,:,:],testX[:,1,:,:]])

fpr, tpr, _ = roc_curve(testY, y_pred)
roc_auc = auc(fpr, tpr)

plt.subplot(1, 2, 2)
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy',linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Test ROC')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# <a id='issue'></a>
# ## What's the Issue?
# As is sadly shown by the results, the model is extremely overfitting. It has a near perfect training accuracy and ROC AUC, but is only slightly better than random guessing on the training set. I think the main issue is that I only have 2200 training examples. For models like Facenet and Deepface, millions of images are used for training. In order to check if the model would benefit from more data, it is useful to graph the training and validation accuracy based off of the number of training samples.

# %%
import pickle
from os.path import isfile
from keras import backend as K
import gc
from time import time

#clear base model from memory
base_model = None
K.clear_session()
gc.collect()

if not isfile('train_acc.p') or not isfile('val_acc.p') or not isfile('samples.p') or not isfile('numpoints.p'):
    numPoints = 10
    pickle.dump(numPoints, open('numpoints.p', 'wb+'))
    train_acc = []
    val_acc = []
    samples = []
else:
    numPoints = pickle.load(open('numpoints.p', 'rb'))
    train_acc = pickle.load(open('train_acc.p', 'rb'))
    val_acc = pickle.load(open('val_acc.p', 'rb'))
    samples = pickle.load(open('samples.p', 'rb'))

if(len(train_acc) < numPoints):
    #print('Starting at iteration '+str(len(train_acc)+1)+' out of '+str(numPoints))
    for i in range(len(train_acc), numPoints-1):
        start = time()
        numSamples = int(trainX.shape[0]*(i+1.0)/numPoints)
        samples.append(numSamples)
        X = trainX[:numSamples,:,:,:]
        y = trainY[:numSamples]
        temp_model = compile_model()
        history = temp_model.fit([X[:,0,:,:],X[:,1,:,:]],y, 
                       validation_data=([testX[:,0,:,:],testX[:,1,:,:]],testY),
                       epochs=50, batch_size=64, verbose=0, 
                        callbacks=[TensorBoard(log_dir="logs/base_model_"+str(numSamples))]).history
        train_acc.append(max(history['acc']))
        val_acc.append(max(history['val_acc']))
        temp_model = None
        K.clear_session()
        gc.collect()
        pickle.dump(train_acc, open('train_acc.p', 'wb+'))
        pickle.dump(val_acc, open('val_acc.p', 'wb+'))
        pickle.dump(samples, open('samples.p', 'wb+'))
        #print('Model '+str(i+1)+': ('+str(train_acc[-1])+', '+str(val_acc[-1])+') in '+str(time()-start)+' seconds')
    samples.append(trainX.shape[0])
    train_acc.append(max(base_history['acc']))
    val_acc.append(max(base_history['val_acc']))
    pickle.dump(train_acc, open('train_acc.p', 'wb+'))
    pickle.dump(val_acc, open('val_acc.p', 'wb+'))
    pickle.dump(samples, open('samples.p', 'wb+'))
    
plt.plot(samples, train_acc)
plt.plot(samples, val_acc)
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('training samples')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# The basic idea of a accuracy vs number of training samples graph is to show if more data will help the model learn. If a model is overfitting to the training data and could use more data to assist in learning, there will be a large gap between the two line(that is the case show here). If the model would not learn better with more data, the train and test accuracy will either converge(if the result is lower than you want than you need to redesign the model or train for more epochs) or flat line(the model is unable to learn no matter how much data it is given)

# %%
trainline = np.poly1d(np.polyfit(samples, train_acc, 1))
valline = np.poly1d(np.polyfit(samples, val_acc, 1))
x = np.linspace(0, 10000, 100)
plt.plot(x, trainline(x))
plt.plot(x, valline(x))
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('training samples')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# The lines shown above are a linear projections of what the training and validation accuracy might look like with more data. In reality, the accuracy would not increase linearly but would increase logirthmically. If I wanted to build a strong model, I would probably need at least 10,000 examples, but 100,000 would be a much safer number. I would also have to train for more epochs, potential with a more complex model, in order to increase the accuracy closer to 100%.

# %% [markdown]
# <a id='more_data'></a>
# ## Getting More Data
#
# In order to get more data, I downloaded the [MegaFace](http://megaface.cs.washington.edu/) dataset. I downloaded the tightly cropped images because they are most similar to the LFW dataset. The dataset is organized with one identity in each folder. In order to use these images for face verification, the data needs to be paired and resized. Because the dataset is extremely large, I am only going to load 100,000 samples.
#
# Every person has at least 3 images. For each person, I will load 3 positive verification examples and 3 negative verification examples. The negative examples will be made off of the next 3 identities in the list because they are shuffled already.

# %%
from os import listdir
from scipy.misc import imread, imresize
from sklearn.utils import shuffle

if not isfile('megafaceX.npy') or not isfile('megafaceY.npy'):
    imsize = (trainX.shape[2], trainX.shape[3])
    megafaceX = np.memmap('megafaceX.npy', dtype='float32', mode='w+', shape=(100000, trainX.shape[1], trainX.shape[2], trainX.shape[3], trainX.shape[4]))
    megafaceY = np.memmap('megafaceY.npy', dtype='float32', mode='w+', shape=(100000))
    identities = listdir('MegafaceIdentities_VGG')
    current_identity = 0
    current_sample = 0
    #shuffle data as it is loaded
    shuffle = np.arange(megafaceX.shape[0])
    np.random.shuffle(shuffle)
    for i, s in enumerate(shuffle):
        #load and resize image 3 positive and 3 negative per identity
        if current_sample == 0:
            img0 = 'MegafaceIdentities_VGG/'+identities[current_identity]+"/"+listdir('MegafaceIdentities_VGG/'+identities[current_identity])[0]
            img1 = 'MegafaceIdentities_VGG/'+identities[current_identity]+"/"+listdir('MegafaceIdentities_VGG/'+identities[current_identity])[1]
            megafaceY[s] = 1
        elif current_sample == 1:
            img0 = 'MegafaceIdentities_VGG/'+identities[current_identity]+"/"+listdir('MegafaceIdentities_VGG/'+identities[current_identity])[0]
            img1 = 'MegafaceIdentities_VGG/'+identities[current_identity+1]+"/"+listdir('MegafaceIdentities_VGG/'+identities[current_identity+1])[0]
            megafaceY[s] = 0
        elif current_sample == 2:
            img0 = 'MegafaceIdentities_VGG/'+identities[current_identity]+"/"+listdir('MegafaceIdentities_VGG/'+identities[current_identity])[1]
            img1 = 'MegafaceIdentities_VGG/'+identities[current_identity]+"/"+listdir('MegafaceIdentities_VGG/'+identities[current_identity])[2]
            megafaceY[s] = 1
        elif current_sample == 3:
            img0 = 'MegafaceIdentities_VGG/'+identities[current_identity]+"/"+listdir('MegafaceIdentities_VGG/'+identities[current_identity])[1]
            img1 = 'MegafaceIdentities_VGG/'+identities[current_identity+2]+"/"+listdir('MegafaceIdentities_VGG/'+identities[current_identity+2])[1]
            megafaceY[s] = 0
        elif current_sample == 4:
            img0 = 'MegafaceIdentities_VGG/'+identities[current_identity]+"/"+listdir('MegafaceIdentities_VGG/'+identities[current_identity])[0]
            img1 = 'MegafaceIdentities_VGG/'+identities[current_identity]+"/"+listdir('MegafaceIdentities_VGG/'+identities[current_identity])[2]
            megafaceY[s] = 1
        elif current_sample == 5:
            img0 = 'MegafaceIdentities_VGG/'+identities[current_identity]+"/"+listdir('MegafaceIdentities_VGG/'+identities[current_identity])[2]
            img1 = 'MegafaceIdentities_VGG/'+identities[current_identity+3]+"/"+listdir('MegafaceIdentities_VGG/'+identities[current_identity+3])[2]
            megafaceY[s] = 0
            current_identity += 1
            current_sample = -1
        megafaceX[s][0] = imresize(imread(img0), imsize)
        megafaceX[s][1] = imresize(imread(img1), imsize)
        current_sample += 1 
        #if i % 1000 == 0:
        #    print("%d%%"%(i/1000))
    
    megafaceX.flush()
    megafaceY.flush()

megafaceX = np.memmap('megafaceX.npy', dtype='float32', mode='r', shape=(100000, trainX.shape[1], trainX.shape[2], trainX.shape[3], trainX.shape[4]))
megafaceY = np.memmap('megafaceY.npy', dtype='float32', mode='r', shape=(100000))

# %% [markdown]
# Just like before, I am displaying some random examples in order to insure the data loaded well.

# %%
for i in range(5):
    plt.subplot(2, 5, i+1)
    plt.axis('off')
    r = randint(0, megafaceX.shape[0]-1)
    plt.imshow(array_to_img(megafaceX[r,0]))
    plt.subplot(2, 5, i+6)
    plt.axis('off')
    plt.imshow(array_to_img(megafaceX[r,1]))

plt.show()

# %% [markdown]
# This time there is not a set validation set. Instead, 30% of the training data will be used specifically for validation. Because I do not have an extremely powerful server, I am only going to using 30,000 samples of th 100,000. This leads to training on about 10 times the data as the basic model. Hopefully, this will be enough to create siginificant improvement.

# %%
more_data_model = compile_model()

files = [f for f in listdir('more_data_model') if isfile(join('more_data_model', f))]
if len(files) > 0:
    more_data_model.load_weights('more_data_model/'+sorted(files)[-1])
    more_data_history = pickle.load(open("more_data_model/history.p", "rb"))
else:
    filepath="more_data_model/weights-improvement-{epoch:02d}-{val_acc:.2f}.hdf5"
    checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=0, save_best_only=True, mode='max')
    tensorboard = TensorBoard(log_dir="logs/more_data_model")
    callbacks_list = [checkpoint, tensorboard]

    more_data_history = more_data_model.fit([megafaceX[:,0,:,:],megafaceX[:,1,:,:]],
              megafaceY[:], validation_split=0.3,
              epochs=50, batch_size=64, callbacks=callbacks_list, verbose=0).history
    pickle.dump(more_data_history, open("more_data_model/history.p", "wb+"))

# %% [markdown]
# <a id='more_data_results'></a>
# ## Results with More Data

# %%
# summarize history for accuracy
plt.plot(more_data_history['acc'])
plt.plot(more_data_history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
y_pred = more_data_model.predict([megafaceX[:70000,0,:,:],megafaceX[:70000,1,:,:]])

fpr, tpr, _ = roc_curve(megafaceY[:70000], y_pred)
roc_auc = auc(fpr, tpr)

plt.subplot(1, 2, 1)
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy',linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Train ROC')
plt.legend(loc="lower right")

y_pred = more_data_model.predict([megafaceX[70000:,0,:,:],megafaceX[70000:,1,:,:]])

fpr, tpr, _ = roc_curve(megafaceY[70000:], y_pred)
roc_auc = auc(fpr, tpr)

plt.subplot(1, 2, 2)
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy',linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Validation ROC')
plt.legend(loc="lower right")
plt.show()

# %%
y_pred = more_data_model.predict([testX[:,0,:,:],testX[:,1,:,:]])

fpr, tpr, _ = roc_curve(testY, y_pred)
roc_auc = auc(fpr, tpr)

plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy',linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Test ROC')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# <a id='conclusion'></a>
# ## Conclusion
